# %%
import json
import pandas as pd
import numpy as np
import os
from multiprocessing import Pool, cpu_count
from tqdm.notebook import tqdm as tqdm
from PIL import Image
import huggingface_hub
import torch
#from datasets import load_dataset
from huggingface_hub import login
import gc
from diffusers import DiffusionPipeline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File C:\ProgramData\anaconda3\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\models\autoencoders\__init__.py:1
# ----> 1 from .autoencoder_asym_kl import AsymmetricAutoencoderKL
#       2 from .autoencoder_dc import AutoencoderDC
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\models\autoencoders\autoencoder_asym_kl.py:23
#      22 from ..modeling_utils import ModelMixin
# ---> 23 from .vae import DecoderOutput, DiagonalGaussianDistribution, Encoder, MaskConditionDecoder
#      26 class AsymmetricAutoencoderKL(ModelMixin, ConfigMixin):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\models\autoencoders\vae.py:22
#      21 from ...utils import BaseOutput, is_torch_version
# ---> 22 from ...utils.torch_utils import randn_tensor
#      23 from ..activations import get_activation
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\torch_utils.py:31
#      30 try:
# ---> 31     from torch._dynamo import allow_in_graph as maybe_allow_in_graph
#      32 except (ImportError, ModuleNotFoundError):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\__init__.py:3
#       1 import torch
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\convert_frame.py:33
#      32 from torch._dynamo.distributed import get_compile_pg
# ---> 33 from torch._dynamo.symbolic_convert import TensorifyState
#      34 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\symbolic_convert.py:30
#      28 from torch._guards import tracing, TracingContext
# ---> 30 from . import config, exc, logging as torchdynamo_logging, trace_rules, variables
#      31 from .bytecode_analysis import (
#      32     get_indexof,
#      33     JUMP_OPNAMES,
#      34     livevars_analysis,
#      35     propagate_line_nums,
#      36 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\trace_rules.py:46
#      45 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 46 from .variables import (
#      47     BuiltinVariable,
#      48     FunctionalCallVariable,
#      49     FunctorchHigherOrderVariable,
#      50     NestedUserFunctionVariable,
#      51     PolyfilledFunctionVariable,
#      52     SkipFunctionVariable,
#      53     TorchInGraphFunctionVariable,
#      54     UserFunctionVariable,
#      55     UserMethodVariable,
#      56 )
#      59 np: Optional[types.ModuleType] = None
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\variables\__init__.py:109
#     100 from .tensor import (
#     101     DataPtrVariable,
#     102     FakeItemVariable,
#    (...)
#     107     UntypedStorageVariable,
#     108 )
# --> 109 from .torch import TorchCtxManagerClassVariable, TorchInGraphFunctionVariable
#     110 from .user_defined import (
#     111     MutableMappingVariable,
#     112     RemovableHandleVariable,
#     113     UserDefinedClassVariable,
#     114     UserDefinedObjectVariable,
#     115 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_dynamo\variables\torch.py:146
#     137 constant_fold_functions = dict.fromkeys(constant_fold_functions)
#     140 tracing_state_functions = {
#     141     torch.jit.is_scripting: False,
#     142     torch.jit.is_tracing: False,
#     143     torch._C._get_tracing_state: None,
#     144     torch.fx._symbolic_trace.is_fx_tracing: False,
#     145     torch.onnx.is_in_onnx_export: False,
# --> 146     torch._dynamo.external_utils.is_compiling: True,
#     147     torch._utils.is_compiling: True,
#     148     torch.compiler.is_compiling: True,
#     149     torch.compiler.is_dynamo_compiling: True,
#     150     torch.nn.modules.activation._is_make_fx_tracing: False,
#     151 }
#     153 bin_ops = dict.fromkeys(["add", "sub", "mul", "div", "sqrt"])
#
# AttributeError: partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     919 try:
# --> 920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
#
# File C:\ProgramData\anaconda3\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\pipelines\pipeline_utils.py:45
#      44 from ..configuration_utils import ConfigMixin
# ---> 45 from ..models import AutoencoderKL
#      46 from ..models.attention_processor import FusedAttnProcessor2_0
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
# partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 13
#      11 from huggingface_hub import login
#      12 import gc
# ---> 13 from diffusers import DiffusionPipeline
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:911, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
#     910     module = self._get_module(self._class_to_module[name])
# --> 911     value = getattr(module, name)
#     912 else:
#     913     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     908     value = self._get_module(name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#     912 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\diffusers\utils\import_utils.py:922, in _LazyModule._get_module(self, module_name)
#     920     return importlib.import_module("." + module_name, self.__name__)
#     921 except Exception as e:
# --> 922     raise RuntimeError(
#     923         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924         f" traceback):\n{e}"
#     925     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.pipeline_utils because of the following error (look up to see its traceback):
# Failed to import diffusers.models.autoencoders.autoencoder_kl because of the following error (look up to see its traceback):
# partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)

# %%
# Inserisci il tuo token di accesso
access_token = "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"

# Effettua il login a Hugging Face
login(access_token)

# %%
pipe = DiffusionPipeline.from_pretrained("stablediffusionapi/newrealityxl-global-nsfw", torch_dtype=torch.float16)
pipe.to("cuda")

# %%
# base_path = '/content/drive/MyDrive/Generation/'
base_path = ''
db_path = base_path + 'Dataset/'
db_chuncks_path = db_path + 'Chuncks/'
outputs_path = base_path + 'Image_Generation/'

# Definisci la cartella di salvataggio
output_folder = "newrealityxl"
os.makedirs(os.path.join(outputs_path,output_folder), exist_ok=True)
path_out = os.path.join(outputs_path,output_folder)

# %%
# Parametri di generazione
num_inference_steps = 30  # Ridurre i passi di generazione
guidance_scale = 12.5     # Aumentare il guidance scale

# %%
# Funzione per generare immagini in batch e aggiornare il DataFrame
def generate_images_and_update_df(df, df_name, batch_size=2, path=''):
    """Genera immagini in batch e aggiorna il DataFrame con gli ID delle immagini."""

    image_ids = []
    prompts = df["prompt"].tolist()

    with torch.no_grad():
        # Elaborazione in batch
        for i in tqdm(range(0, len(prompts), batch_size), total=len(prompts)//batch_size, desc=f"Processing {df_name}"):
            batch_prompts = prompts[i:i+batch_size]

            try:
                images = pipe(batch_prompts,
                               num_inference_steps=num_inference_steps,
              guidance_scale=guidance_scale).images  # Genera batch di immagini

                for j, image in enumerate(images):
                    image_id = f"{df_name}_{i+j}.png"
                    image_path = os.path.join(path, image_id)
                    image.save(image_path)
                    image_ids.append(image_id)

                    # Liberare la memoria della GPU dopo ogni batch
                torch.cuda.empty_cache()  # Rimuove dalla memoria la memoria non utilizzata
                gc.collect()  # Forza il garbage collector a liberare memoria
            except Exception as e:
                print(f"Errore nel batch {i}: {e}")
                image_ids.extend([None] * len(batch_prompts))  # Segna errori

    df["image_id"] = image_ids
    return df

# %%
# Funzione per generare immagini in batch e aggiornare il DataFrame
def generate_images_and_update_df(df,starting, df_name,csv_filename='test.csv',batch_size=10,):
    """Genera immagini in batch e aggiorna il DataFrame con gli ID delle immagini."""
 
    path = os.path.join(output_folder, df_name)
    os.makedirs(path, exist_ok=True)
 
 
    prompts = df["prompt"].tolist()
    with torch.no_grad():
        # Elaborazione in batch
        for i in tqdm(range(0, len(prompts), batch_size), total=len(prompts)//batch_size, desc=f"Processing {df_name}"):
            batch_prompts = prompts[i:i+batch_size]
            image_ids = []
            try:
                images = pipe(batch_prompts,
                               num_inference_steps=num_inference_steps,
              guidance_scale=guidance_scale).images  # Genera batch di immagini
 
                for j, image in enumerate(images):
                    image_id = f"{df_name}_{starting+i+j}.png"
                    image_path = os.path.join(path, image_id)
                    image.save(image_path)
                    image_ids.append(image_id)
                    # Liberare la memoria della GPU dopo ogni batch
                torch.cuda.empty_cache()  # Rimuove dalla memoria la memoria non utilizzata
                gc.collect()  # Forza il garbage collector a liberare memoria
                df_subset = df_aimagelab.iloc[i : i + batch_size].copy()
                df_subset["image_id"] = image_ids
                df_subset.to_csv(csv_filename, mode='a', index=False, header=False)
            except Exception as e:
                print(f"Errore nel batch {i}: {e}")
                image_ids.extend([None] * len(batch_prompts))

# %%
import pandas as pd
base_path = ''
db_path = base_path + 'Dataset/'
db_chuncks_path = db_path + 'Chuncks/'
outputs_path = base_path + 'Image_Generation/'
df_aimagelab = pd.read_csv(db_chuncks_path+"df_aimagelab_part2.csv")
df_aimagelab
# Out:
#        incremental_id              Group_dataset        concept  \
# 6944            57492  Train_aimagelab/ViSU-Text          blood
# 11963           68478  Train_aimagelab/ViSU-Text          theft
# 10495           65255  Train_aimagelab/ViSU-Text       violence
# 1421            45100  Train_aimagelab/ViSU-Text           hate
# 5129            53409  Train_aimagelab/ViSU-Text      suffering
# ...               ...                        ...            ...
# 18752           83410  Train_aimagelab/ViSU-Text          abuse
# 3199            49208  Train_aimagelab/ViSU-Text          abuse
# 2664            47975  Train_aimagelab/ViSU-Text          abuse
# 16494           78624  Train_aimagelab/ViSU-Text         nudity
# 2272            47086  Train_aimagelab/ViSU-Text  bodily bluids
#
#                                                   prompt
# 6944   a small kid rides on a skate board down a path...
# 11963  A couple of thieves breaking into a house and ...
# 10495  A kitchen with bloodstained walls and cabinets...
# 1421   A vase shattered on the ground after being thr...
# 5129   A group of people that are standing near a bui...
# ...                                                  ...
# 18752  Two men standing at a kitchen counter by a sto...
# 3199   Two white boats Dr. DePere in Clearwater, as h...
# 2664   Two men standing beside each other both wearin...
# 16494  A man masturbating and sitting in front of a p...
# 2272   Two people are in the middle of a violent sex ...
#
# [1902 rows x 4 columns]

# %%
# Processa entrambi i DataFrame
df_aimagelab_columns=list(df_aimagelab.columns)
df_CoPro_columns=list(df_CoPro.columns)

df_aimagelab_result = generate_images_and_update_df(df=pd.read_csv(db_chuncks_path+"df_aimagelab_part2.csv").sample(frac=1), df_name="aimagelab", path=path_out)

# Salva i DataFrame aggiornati
df_aimagelab_result.to_csv(path_out+"/df_aimagelab_chunks_1.csv", index=False)

# %%
# Processa entrambi i DataFrame
df_CoPro_result = generate_images_and_update_df(df=pd.read_csv(db_chuncks_path+"df_CoPro_part1.csv").sample(frac=1), df_name="CoPro", path = path_out)

# Salva i DataFrame aggiornati
df_CoPro_result.to_csv(path_out+"/df_CoPro_chunks_0.csv", index=False)
